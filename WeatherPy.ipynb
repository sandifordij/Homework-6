# %%
import os
import time
import random
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
from scipy.stats import linregress
from pprint import pprint
from citipy import citipy
from api_keys import weather_api_key
from api_keys import g_key

# %%
# Construct city list from the jason file that is distributed by api.openweather.org, save the list to "allcities.csv"

with open('city.list.json', 'r',encoding='utf-8') as jsonfile:
    jsndata = json.load(jsonfile)

ids = []
nam = []
country = []
lat = []
lon = []

for i in range(len(jsndata)):
    ids.append(jsndata[i]['id'])
    nam.append(jsndata[i]['name'].lower())
    country.append(jsndata[i]['country'])
    # need to lower the letter case because citipy uses lower case letters
    lat.append(jsndata[i]['coord']['lat'])
    lon.append(jsndata[i]['coord']['lon'])
    
dftemp = pd.DataFrame({'id':ids,'City':nam,'Country':country,'Lat':lat,'Lng':lon})
dftemp.to_csv("output_data/allcities.csv", index=False, header=True)

# %%
# Read dfcities.csv file into dataframe, previous cell is not required to run once the dfcities.csv is saved

dfcities = pd.read_csv("output_data/allcities.csv", encoding="utf-8")
dfcities = dfcities.set_index('City')
dfcities.head()
# Out:
#                        id Country        Lat        Lng
# City
# hurzuf             707860      UA  44.549999  34.283333
# novinki            519188      RU  55.683334  37.666668
# gorkhā            1283378      NP  28.000000  84.633331
# state of haryāna  1270260      IN  29.000000  76.000000
# holubynka          708546      UA  44.599998  33.900002

# %%
# Select 500 unique cities and save the data into dfselected.csv

ncities = 500
namsel = []
idsel = []
countrysel = []
latsel = []
lonsel = []
i = 0
while(i < ncities):
    i = i+1
    latitude = random.uniform(-90.0,90.0)
    longitude = random.uniform(-180.0,180.0)
    city = citipy.nearest_city(latitude,longitude)
    try:
        id = int(dfcities.loc[city.city_name]['id'])
        try:
            itemp = idsel.index(id)
            i = i - 1
        except:
            idsel.append(id)
            namsel.append(city.city_name)
            countrysel.append(dfcities.loc[city.city_name]['Country'])
            latsel.append(dfcities.loc[city.city_name]['Lat'])
            lonsel.append(dfcities.loc[city.city_name]['Lng'])
    except:
        i = i - 1

dftemp = pd.DataFrame({'City':namsel,'id':idsel,'Country':countrysel,'Lat':latsel,'Lng':lonsel})
dftemp.to_csv("output_data/dfselected.csv", index=False, header=True)

# %%
# Read dfselected.csv file into dataframe, previous cells are not required to run once the dfselected.csv is saved
# generate scatter plot to make sure that cities are distributed throughout the globe

dfselected = pd.read_csv("output_data/dfselected.csv", encoding="utf-8")

# print total # of selected cities
print(len(dfselected)) 

# check if the dataframe has the right format
print(dfselected.head())

# generate the scatter plot to make sure that the cities are evenly distributed throughout the globe
plt.scatter(dfselected["Lng"],dfselected["Lat"],marker="o",facecolors="red",edgecolors="black",s=50,alpha=0.75)
# Out:
# 500
#                    City       id Country        Lat         Lng
# 0          punta arenas  3874787      CL -53.150002  -70.916672
# 1            chokurdakh  2126123      RU  70.633331  147.916672
# 2            marienburg  3383570      SR   5.846910  -55.021591
# 3  bernardino de campos  3470059      BR -23.013060  -49.474171
# 4                yantal  2055868      RU  56.847099  105.254204

# %%
# Request weather informatiton for the selected cities and save into a json file weatherlist.json

jsnlist = []

i = 0
waitingtime = 0
ncities = len(dfselected)
while i < ncities:
    id = dfselected['id'][i]
    url = f"http://api.openweathermap.org/data/2.5/forecast?id={id}&units=imperial&APPID={weather_api_key}"
    jsn = requests.get(url).json()
    try:
        print('City-{0}: {1}'.format(i,jsn['city']['name']))
        jsnlist.append(jsn)
        i = i + 1
        waitingtime = 0
    except:
        waitingtime = waitingtime + 1
        print(f"Waiting {waitingtime} seconds")
        time.sleep(1)
    
with open('output_data/weatherlist.json', 'w') as jsonfile:
    json.dump(jsnlist, jsonfile)
# Out:
# City-0: Punta Arenas
# City-1: Chokurdakh
# City-2: Marienburg
# City-3: Bernardino de Campos
# City-4: Yantal
# City-5: Cidreira
# City-6: Ahipara
# City-7: Hermanus
# City-8: Hithadhoo
# City-9: Vaini
# City-10: Torbay
# City-11: Khon Buri
# City-12: Upernavik
# City-13: Arlit
# City-14: Buin
# City-15: Bathsheba
# City-16: Mandan
# City-17: Rikitea
# City-18: Tuktoyaktuk
# City-19: Bengkulu
# City-20: Los Llanos de Aridane
# City-21: Puerto Ayora
# City-22: Morondava
# City-23: Arraial do Cabo
# City-24: Lambarene
# City-25: Kavieng
# City-26: Ushuaia
# City-27: Qaanaaq
# City-28: Kousseri
# City-29: Nefteyugansk
# City-30: Cape Town
# City-31: Parksville
# City-32: Yellowknife
# City-33: Khatanga
# City-34: Norman Wells
# City-35: Hilo
# City-36: Bluff
# City-37: Atuona
# City-38: Manicore
# City-39: Cedar City
# City-40: Ukiah
# City-41: Codrington
# City-42: Provideniya
# City-43: Tanout
# City-44: Nelson Bay
# City-45: Arua
# City-46: New Norfolk
# City-47: Isangel
# City-48: Goksun
# City-49: Traverse City
# City-50: Kodiak
# City-51: Lompoc
# City-52: Bambous Virieux
# City-53: Berlevag
# City-54: Zyryanka
# City-55: Lavrentiya
# City-56: Kununurra
# City-57: Avarua
# City-58: Thinadhoo
# City-59: Santa Vitoria
# City-60: Sitka
# City-61: Axim
# City-62: Port Alfred
# City-63: Iqaluit
# City-64: Manggar
# City-65: Kaeo
# City-66: Totness
# City-67: Seoul
# City-68: Keti Bandar
# City-69: Narsaq
# City-70: Sao Felix do Xingu
# City-71: Bredasdorp
# City-72: Klaksvik
# City-73: Nanortalik
# City-74: Fallon
# City-75: Mahebourg
# City-76: Tieli
# City-77: Severo-Kurilsk
# City-78: Tilichiki
# City-79: Capitao Poco
# City-80: Bandarbeyla
# City-81: Ankang
# City-82: Seybaplaya
# City-83: Ancud
# City-84: Najran
# City-85: Bali Chak
# City-86: Tabou
# City-87: Derzhavinsk
# City-88: Baykit
# City-89: North Platte
# City-90: Faanui
# City-91: Chernyshevskiy
# City-92: Ketchikan
# City-93: Pevek
# City-94: Paamiut
# City-95: Pisco
# City-96: Lasa
# City-97: Bernay
# City-98: Panguna
# City-99: Alugan
# City-100: Broken Hill
# City-101: Ostrovnoy
# City-102: Bubaque
# City-103: Malyn
# City-104: Arman
# City-105: Atar
# City-106: Leningradskiy
# City-107: Ilulissat
# City-108: Prachuap Khiri Khan
# City-109: Guerrero Negro
# City-110: Lufilufi
# City-111: East London
# City-112: Nianzishan
# City-113: Teguldet
# City-114: Mar del Plata
# City-115: Buala
# City-116: Yulara
# City-117: Marilia
# City-118: Lower Hutt
# City-119: Bam
# City-120: Daud Khel
# City-121: Urengoy
# City-122: Kahului
# City-123: Baruun-Urt
# City-124: Batagay-Alyta
# City-125: Caibarien
# City-126: Dzilam Gonzalez
# City-127: Villa Carlos Paz
# City-128: Xixiang
# City-129: Yining
# City-130: Macae
# City-131: Pagudpud
# City-132: Lakes Entrance
# City-133: Port Hardy
# City-134: Hay River
# City-135: Lebu
# City-136: Sampit
# City-137: Comodoro Rivadavia
# City-138: Ulaanbaatar
# City-139: Humberto de Campos
# City-140: Ippy
# City-141: Tikrit
# City-142: Olavarria
# City-143: Yar-Sale
# City-144: Dikson
# City-145: Shahr-e Babak
# City-146: Keita
# City-147: Beitbridge
# City-148: Talnakh
# City-149: Alihe
# City-150: Kapaa
# City-151: Yamada
# City-152: San Policarpo
# City-153: Pangai
# City-154: Ikom
# City-155: Wasilla
# City-156: Vaasa
# City-157: Inhambane
# City-158: Great Bend
# City-159: Pitimbu
# City-160: Culebra
# City-161: Baie-Comeau
# City-162: Piranhas
# City-163: Pringsewu
# City-164: Maldonado
# City-165: Clyde River
# City-166: Tuatapere
# City-167: Cabo San Lucas
# City-168: Lata
# City-169: Lahaina
# City-170: Muisne
# City-171: Ningbo
# City-172: Mandalgovi
# City-173: Neutraubling
# City-174: Koutiala
# City-175: Mareeba
# City-176: Shache
# City-177: Sisimiut
# City-178: Along
# City-179: Deyang
# City-180: Tiksi
# City-181: Kokorevka
# City-182: Uribia
# City-183: Conceicao do Araguaia
# City-184: Tikapur
# City-185: Puerto Leguizamo
# City-186: Sarangani
# City-187: Salalah
# City-188: Tasiilaq
# City-189: Roald
# City-190: Plettenberg Bay
# City-191: Hami
# City-192: Zanjan
# City-193: Maningrida
# City-194: North Battleford
# City-195: Alor Setar
# City-196: Chokwe
# City-197: Libreville
# City-198: Cherskiy
# City-199: Meiganga
# City-200: Karlskrona
# City-201: Kawalu
# City-202: Claresholm
# City-203: Brigantine
# City-204: Mehran
# City-205: Tchaourou
# City-206: Polazna
# City-207: Coquimbo
# City-208: Calvinia
# City-209: Dembi Dolo
# City-210: Ambilobe
# City-211: Adrar
# City-212: Longyearbyen
# City-213: Tevaitoa
# City-214: Vao
# City-215: Rawatsar
# City-216: Kipini
# City-217: Hagere Hiywet
# City-218: Samoded
# City-219: Korla
# City-220: Lahad Datu
# City-221: Beidao
# City-222: Taluya
# City-223: Terskaya
# City-224: Kavaratti
# City-225: Touros
# City-226: Skjervoy
# City-227: Necochea
# City-228: Saskylakh
# City-229: Namibe
# City-230: Hailar
# City-231: Waipawa
# City-232: Bernau
# City-233: Gudari
# City-234: Grindavik
# City-235: Chukhloma
# City-236: Havoysund
# City-237: Novoomskiy
# City-238: Minab
# City-239: Dhilwan
# City-240: Sarana
# City-241: Maragogi
# City-242: Liberal
# City-243: Sao Miguel do Araguaia
# City-244: Kruisfontein
# City-245: Nyurba
# City-246: Havre-Saint-Pierre
# City-247: Petropavlovsk-Kamchatskiy
# City-248: Pangnirtung
# City-249: Katsuura
# City-250: Turukhansk
# City-251: Iquitos
# City-252: Goderich
# City-253: Pasighat
# City-254: Karratha
# City-255: Zhenlai
# City-256: Laela
# City-257: Suntar
# City-258: Eganville
# City-259: Puri
# City-260: Richards Bay
# City-261: Stokmarknes
# City-262: Metro
# City-263: Konza
# City-264: Kristianstad
# City-265: Dong Hoi
# City-266: Formosa do Rio Preto
# City-267: Doha
# City-268: Meulaboh
# City-269: Vardo
# City-270: Uyuni
# City-271: Rishikesh
# City-272: Nanakuli
# City-273: Viedma
# City-274: Gamboula
# City-275: Ulaangom
# City-276: Kimbe
# City-277: Lokoja
# City-278: Kysyl-Syr
# City-279: Bassano
# City-280: Tazovskiy
# City-281: At-Bashi
# City-282: Maltahohe
# City-283: Port Blair
# City-284: Hasaki
# City-285: Bamnet Narong
# City-286: Vestmanna
# City-287: Ust-Nera
# City-288: Dukat
# City-289: Vanimo
# City-290: Maiduguri
# City-291: Sur
# City-292: Ulladulla
# City-293: Egvekinot
# City-294: Asyut
# City-295: Ust-Tsilma
# City-296: Pangody
# City-297: Chegdomyn
# City-298: Mucurapo
# City-299: La Orilla
# City-300: Nemuro
# City-301: Lorengau
# City-302: Evensk
# City-303: Gorele
# City-304: Zwedru
# City-305: Sao Filipe
# City-306: Bilibino
# City-307: Alyangula
# City-308: Oltu
# City-309: Sao Gabriel da Cachoeira
# City-310: Ampanihy
# City-311: Udachnyy
# City-312: Kongolo
# City-313: Bratsk
# City-314: Payakumbuh
# City-315: Zyryanovsk
# City-316: Puerto Narino
# City-317: Husavik
# City-318: Verkhnyaya Khava
# City-319: Acarau
# City-320: Soeng Sang
# City-321: Fort Nelson
# City-322: Kloulklubed
# City-323: Kilindoni
# City-324: Lodwar
# City-325: Grande Prairie
# City-326: Haines Junction
# City-327: Wuwei
# City-328: Ugoofaaru
# City-329: Merke
# City-330: Bonthe
# City-331: La Ronge
# City-332: Camabatela
# City-333: Aswan
# City-334: Anshun
# City-335: Bordighera
# City-336: Kafue
# City-337: Tarime
# City-338: Matagami
# City-339: Chandpur
# City-340: Deputatskiy
# City-341: Riyadh
# City-342: Saldanha
# City-343: Berdigestyakh
# City-344: Okhotsk
# City-345: Udgir
# City-346: Ous
# City-347: Zhangye
# City-348: Astana
# City-349: Waingapu
# City-350: Eirunepe
# City-351: Srednekolymsk
# City-352: Canasgordas
# City-353: Boueni
# City-354: Nizwa
# City-355: Khonsa
# City-356: Mabaruma
# City-357: Basoko
# City-358: Te Anau
# City-359: Pangkalanbuun
# City-360: Benemerito de las Americas
# City-361: Lafia
# City-362: Yumen
# City-363: Yakeshi
# City-364: Preobrazheniye
# City-365: Aquin
# City-366: Kangaatsiaq
# City-367: Zadar
# City-368: Nova Varos
# City-369: Zhigansk
# City-370: Shumskiy
# City-371: Marrakesh
# City-372: Druzhnaya Gorka
# City-373: Mehamn
# City-374: Nisia Floresta
# City-375: Ossora
# City-376: Wajima
# City-377: Puerto Colombia
# City-378: Sumenep
# City-379: Ayagoz
# City-380: Aasiaat
# City-381: Shieli
# City-382: Santa Isabel do Rio Negro
# City-383: Kyaiklat
# City-384: Tres Lagoas
# City-385: Honiara
# City-386: Murbad
# City-387: Ribas do Rio Pardo
# City-388: Saint-Georges
# City-389: Tynda
# City-390: Tanashi
# City-391: Opuwo
# City-392: Khandyga
# City-393: Chateau-Thierry
# City-394: Sidrolandia
# City-395: Zhuhai
# City-396: Oistins
# City-397: Sassandra
# City-398: Port Moresby
# City-399: Camana
# City-400: Puerto Baquerizo Moreno
# City-401: Labuhan
# City-402: Dalvik
# City-403: Terrace
# City-404: Gilleleje
# City-405: Vila Velha
# City-406: Sernur
# City-407: Cumpas
# City-408: Mandera
# City-409: Brae
# City-410: Nakusp
# City-411: Ko Samui
# City-412: Chermoz
# City-413: Nabire
# City-414: Beringovskiy
# City-415: Smithers
# City-416: Cabedelo
# City-417: Sibolga
# City-418: Alofi
# City-419: Araouane
# City-420: Funtua
# City-421: Sembakung
# City-422: Humaita
# City-423: Taoudenni
# City-424: Kannauj
# City-425: Sawakin
# City-426: Sechura
# City-427: Finschhafen
# City-428: Piacabucu
# City-429: Tommot
# City-430: Pyay
# City-431: Abakaliki
# City-432: Vasai
# City-433: Rio Gallegos
# City-434: Sioux Lookout
# City-435: Toamasina
# City-436: Usinsk
# City-437: Zhumadian
# City-438: Oranjemund
# City-439: Jhargram
# City-440: Vrbove
# City-441: Muravlenko
# City-442: Enugu
# City-443: Dumbea
# City-444: Jimo
# City-445: Nyrob
# City-446: Baherden
# City-447: Grimshaw
# City-448: Narnaul
# City-449: Cocobeach
# City-450: Garissa
# City-451: Zhatay
# City-452: Llangefni
# City-453: Abu Dhabi
# City-454: Trairi
# City-455: Lolodorf
# City-456: Bambanglipuro
# City-457: Moranbah
# City-458: Miyako
# City-459: Houma
# City-460: Bah
# City-461: Hobyo
# City-462: Snasa
# City-463: Saharsa
# City-464: Am Timan
# City-465: Kosonsoy
# City-466: Berani
# City-467: Kihei
# City-468: Boyolangu
# City-469: Sal Rei
# City-470: Elizabeth City
# City-471: Ketou
# City-472: Asau
# City-473: Waddan
# City-474: Caernarfon
# City-475: Kulhudhuffushi
# City-476: Bom Jesus da Lapa
# City-477: Marsh Harbour
# City-478: Fernandopolis
# City-479: Goundam
# City-480: Tromso
# City-481: Kochki
# City-482: Aklavik
# City-483: Nouadhibou
# City-484: Jacareacanga
# City-485: Awash
# City-486: Oktyabrskoye
# City-487: Plant City
# City-488: Kirakira
# City-489: Port-Cartier
# City-490: Gwadar
# City-491: Prince Rupert
# City-492: Santee
# City-493: Sheltozero
# City-494: Ust-Koksa
# City-495: Sokoni
# City-496: Sorland
# City-497: Santiago del Estero
# City-498: Rongcheng
# City-499: Kapuskasing

# %%
# Read weatherlist.json and dfselected.csv and create cities.csv

with open('output_data/weatherlist.json', 'r',encoding='utf-8') as jsonfile:
    weatherlist = json.load(jsonfile)

# Read again the selected cities just in case if the notebook is opened again
cities = pd.read_csv("output_data/dfselected.csv", encoding="utf-8")
del cities['id']

cities['Date'] = [weatherlist[i]['list'][0]['dt'] for i in range(len(weatherlist))]
cities['Cloudiness'] = [weatherlist[i]['list'][0]['clouds']['all'] for i in range(len(weatherlist))]
cities['Humidity'] = [weatherlist[i]['list'][0]['main']['humidity'] for i in range(len(weatherlist))]
cities['Max Temp'] = [weatherlist[i]['list'][0]['main']['temp_max'] for i in range(len(weatherlist))]
cities['Wind Speed'] = [weatherlist[i]['list'][0]['wind']['speed'] for i in range(len(weatherlist))]

# Save the result into cities.csv file
cities.to_csv("output_data/cities.csv", index=False, header=True)

# %%
# read the cities.csv to create dataframe, previous cells are not needed to be executed as long as cities.csv was created

cities = pd.read_csv("output_data/cities.csv", encoding="utf-8")
cities.head()
# Out:
#                    City Country        Lat         Lng        Date  \
# 0          punta arenas      CL -53.150002  -70.916672  1569207600
# 1            chokurdakh      RU  70.633331  147.916672  1569207600
# 2            marienburg      SR   5.846910  -55.021591  1569207600
# 3  bernardino de campos      BR -23.013060  -49.474171  1569207600
# 4                yantal      RU  56.847099  105.254204  1569207600
#
#    Cloudiness  Humidity  Max Temp  Wind Speed
# 0          90        84     43.97       11.34
# 1           0        61     36.52        9.82
# 2          58        82     82.31       19.17
# 3          60        70     59.09       19.77
# 4          87        62     62.47        4.68

# %%
# import time
# convert datetime to 10 digit value
# my_time = time.strptime("09/22/19", "%m/%d/%y")
# timevalue = time.mktime(my_time)
# print(timevalue)

ts = time.gmtime(cities['Date'][0])
# print(time.strftime("%m/%d/%Y %H:%M:%S", ts))
datestr = time.strftime("%x",ts)
plt.scatter(cities['Lat'],cities['Max Temp'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()
plt.title(f"City Latitude vs. Max Temperature ({datestr})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("output_data/fig1.png")
plt.show()

# %%
ts = time.gmtime(cities['Date'][0])
datestr = time.strftime("%x",ts)
plt.scatter(cities['Lat'],cities['Humidity'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()
plt.title(f"City Latitude vs. Humidity ({datestr})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("output_data/fig2.png")
plt.show()

# %%
ts = time.gmtime(cities['Date'][0])
datestr = time.strftime("%x",ts)
plt.scatter(cities['Lat'],cities['Cloudiness'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()
plt.title(f"City Latitude vs. Cloudiness ({datestr})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("output_data/fig3.png")
plt.show()

# %%
ts = time.gmtime(cities['Date'][0])
datestr = time.strftime("%x",ts)
plt.scatter(cities['Lat'],cities['Wind Speed'], marker="o", facecolors="blue", edgecolors="black",s=30, alpha=0.75)
plt.grid()
plt.title(f"City Latitude vs. Wind Speed ({datestr})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("output_data/fig4.png")
plt.show()

# %%
nothern = cities.loc[cities["Lat"] >= 0.0]
nothern.reset_index(inplace=True)

southern = cities.loc[cities["Lat"] < 0.0]
southern.reset_index(inplace=True)

# %%
# Define plotting function

def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    plt.savefig(f"output_data/fig{ifig}.png")
    plt.show()

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression

xlbl = "Lat"
ylbl = "Max Temp"
lblpos = (0,25)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: -0.8162328591308727

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression

xlbl = "Lat"
ylbl = "Max Temp"
lblpos = (-55,90)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,6)
# Out:
# The r-squared is: 0.7122172176566883

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (45,10)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,7)
# Out:
# The r-squared is: 0.015825572899049192

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (-55,15)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,8)
# Out:
# The r-squared is: 0.15962027604912832

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (20,40)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,9)
# Out:
# The r-squared is: 0.10204366115378848

# %%
# Sourhern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (-55,50)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,10)
# Out:
# The r-squared is: 0.16872956866693228

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (0,30)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,11)
# Out:
# The r-squared is: 0.16378304462231275

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (-25,33)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,12)
# Out:
# The r-squared is: -0.38921268213200955

# %% [markdown]
# # Observations
# 1. As expected, temperature correlates well with the latitude. As latitude moves away from equator, temperature also decreases
# 2. It seems that there is no correlation between humidity and latitude
# 3. Even though there is very little correlation between wind speed and latitude, wind speed tends to be higher near arctic and antarctic
